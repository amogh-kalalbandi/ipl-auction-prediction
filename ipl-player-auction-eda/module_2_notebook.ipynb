# %%
import pandas as pd

# %%
import xgboost as xgb

# %%
from hyperopt import fmin, tpe, hp, STATUS_OK, Trials
from hyperopt.pyll import scope

# %%
from sklearn.feature_extraction import DictVectorizer

# %%
from sklearn.metrics import mean_squared_error

# %%
import mlflow

mlflow.set_tracking_uri("sqlite:///mlflow.db")
mlflow.set_experiment("xgboost-autlog-experiment-2")
# Out:
# 2023/05/25 08:27:47 INFO mlflow.tracking.fluent: Experiment with name 'xgboost-autlog-experiment-2' does not exist. Creating a new experiment.
# <Experiment: artifact_location='./mlruns/3', creation_time=1684983467538, experiment_id='3', last_update_time=1684983467538, lifecycle_stage='active', name='xgboost-autlog-experiment-2', tags={}>

# %%
def objective(e):
    with mlflow.start_run():
        mlflow.set_tag("model", "xgboost")
        mlflow.log_params(params)
        booster = xgb.train(
            params=params,
            dtrain=train,
            num_boost_round=30,
            evals=[(valid, "validation")],
            early_stopping_rounds=15
        )
        y_pred = booster.predict(valid)
        rmse = mean_squared_error(y_val, y_pred, squared=False)
        
        mlflow.log_metric("rmse", rmse)
        
    return {'loss': rmse, 'status': STATUS_OK}

# %%
def read_dataframe(filename):
    if filename.endswith('.csv'):
        df = pd.read_csv(filename)

        df.tpep_dropoff_datetime = pd.to_datetime(df.tpep_dropoff_datetime)
        df.tpep_pickup_datetime = pd.to_datetime(df.tpep_pickup_datetime)
    elif filename.endswith('.parquet'):
        df = pd.read_parquet(filename)

    df['duration'] = df.tpep_dropoff_datetime - df.tpep_pickup_datetime
    df.duration = df.duration.apply(lambda td: td.total_seconds() / 60)

    df = df[(df.duration >= 1) & (df.duration <= 60)]

    categorical = ['PULocationID', 'DOLocationID']
    df[categorical] = df[categorical].astype(str)
    
    return df

# %%
df_train = read_dataframe('/Users/temp/Documents/projects/ml_ops_zoomcamp/data/yellow_tripdata_2022-01.parquet')
df_val = read_dataframe('/Users/temp/Documents/projects/ml_ops_zoomcamp/data/yellow_tripdata_2022-02.parquet')

# %%
len(df_train), len(df_val)
# Out:
# (2421440, 2918187)

# %%
df_train['PU_DO'] = df_train['PULocationID'] + '_' + df_train['DOLocationID']
df_val['PU_DO'] = df_val['PULocationID'] + '_' + df_val['DOLocationID']

# %%
df_train_partial = df_train[:100000].copy()
df_val_partial = df_val[:100000].copy()

# %%
def prepare_training_and_validation_data(df_train, df_val):
    df_train['PU_DO'] = df_train['PULocationID'] + '_' + df_train['DOLocationID']
    df_val['PU_DO'] = df_val['PULocationID'] + '_' + df_val['DOLocationID']

    categorical = ['PU_DO'] #'PULocationID', 'DOLocationID']
    numerical = ['trip_distance']

    dv = DictVectorizer()

    train_dicts = df_train[categorical + numerical].to_dict(orient='records')
    X_train = dv.fit_transform(train_dicts)

    val_dicts = df_val[categorical + numerical].to_dict(orient='records')
    X_val = dv.transform(val_dicts)

    target = 'duration'
    y_train = df_train[target].values
    y_val = df_val[target].values

    return {
        'X_train': X_train,
        'y_train': y_train,
        'X_val': X_val,
        'y_val': y_val
    }

# %%
train = xgb.DMatrix(X_train, label=y_train)
valid = xgb.DMatrix(X_val, label=y_val)

# %%
search_scope = {
    'max_depth': scope.int(hp.quniform('max_depth', 4, 100, 1)),
    'learning_rate': hp.loguniform('learning_rate', -3, 0),
    'reg_alpha': hp.loguniform('reg_alpha', -5, -1),
    'reg_lambda': hp.loguniform('reg_lambda', -6, -1),
    'min_child_weight': hp.loguniform('min_child_weight', -1, 3),
    'objective': 'reg:linear',
    'seed': 42
}

# %%
best_result = fmin(
    fn=objective,
    space=search_scope,
    algo=tpe.suggest,
    max_evals=50,
    trials=Trials()
)
# Out:
# [00:00:12] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-cpython-37/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [0]	validation-rmse:15.01831
# [1]	validation-rmse:13.24024
# [2]	validation-rmse:11.85519
# [3]	validation-rmse:10.78265
# [4]	validation-rmse:9.95407
# [5]	validation-rmse:9.31455
# [6]	validation-rmse:8.82275
# [7]	validation-rmse:8.44416
# [8]	validation-rmse:8.15176
# [9]	validation-rmse:7.92331
# [10]	validation-rmse:7.74558
# [11]	validation-rmse:7.60698
# [12]	validation-rmse:7.49782
# [13]	validation-rmse:7.41229
# [14]	validation-rmse:7.34512
# [15]	validation-rmse:7.29239
# [16]	validation-rmse:7.24937
# [17]	validation-rmse:7.21618
# [18]	validation-rmse:7.18860
# [19]	validation-rmse:7.16655
# [20]	validation-rmse:7.14955
# [21]	validation-rmse:7.13531
# [22]	validation-rmse:7.12397
# [23]	validation-rmse:7.11566
# [24]	validation-rmse:7.10780
# [25]	validation-rmse:7.10254
# [26]	validation-rmse:7.09806
# [27]	validation-rmse:7.09391
# [28]	validation-rmse:7.09028
# [29]	validation-rmse:7.08780
# [00:00:16] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-cpython-37/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [0]	validation-rmse:16.60291
# [1]	validation-rmse:15.95909
# [2]	validation-rmse:15.35730
# [3]	validation-rmse:14.79521
# [4]	validation-rmse:14.27002
# [5]	validation-rmse:13.77971
# [6]	validation-rmse:13.32181
# [7]	validation-rmse:12.89530
# [8]	validation-rmse:12.49734
# [9]	validation-rmse:12.12580
# [10]	validation-rmse:11.77981
# [11]	validation-rmse:11.45651
# [12]	validation-rmse:11.15626
# [13]	validation-rmse:10.87638
# [14]	validation-rmse:10.61601
# [15]	validation-rmse:10.37382
# [16]	validation-rmse:10.14852
# [17]	validation-rmse:9.93921
# [18]	validation-rmse:9.74424
# [19]	validation-rmse:9.56290
# [20]	validation-rmse:9.39458
# [21]	validation-rmse:9.23758
# [22]	validation-rmse:9.09177
# [23]	validation-rmse:8.95649
# [24]	validation-rmse:8.83038
# [25]	validation-rmse:8.71347
# [26]	validation-rmse:8.60456
# [27]	validation-rmse:8.50362
# [28]	validation-rmse:8.40953
# [29]	validation-rmse:8.32182
# [00:00:35] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-cpython-37/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [0]	validation-rmse:15.64117
# [1]	validation-rmse:14.25251
# [2]	validation-rmse:13.09123
# [3]	validation-rmse:12.11071
# [4]	validation-rmse:11.29903
# [5]	validation-rmse:10.61201
# [6]	validation-rmse:10.05147
# [7]	validation-rmse:9.57807
# [8]	validation-rmse:9.19085
# [9]	validation-rmse:8.86417
# [10]	validation-rmse:8.58952
# [11]	validation-rmse:8.36244
# [12]	validation-rmse:8.17596
# [13]	validation-rmse:8.01950
# [14]	validation-rmse:7.88597
# [15]	validation-rmse:7.77193
# [16]	validation-rmse:7.67690
# [17]	validation-rmse:7.60130
# [18]	validation-rmse:7.53318
# [19]	validation-rmse:7.47905
# [20]	validation-rmse:7.42953
# [21]	validation-rmse:7.39044
# [22]	validation-rmse:7.35602
# [23]	validation-rmse:7.32763
# [24]	validation-rmse:7.30428
# [25]	validation-rmse:7.28388
# [26]	validation-rmse:7.26788
# [27]	validation-rmse:7.25318
# [28]	validation-rmse:7.24123
# [29]	validation-rmse:7.23079
# [00:01:13] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-cpython-37/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [0]	validation-rmse:16.66105
# [1]	validation-rmse:16.06859
# [2]	validation-rmse:15.51142
# [3]	validation-rmse:14.98783
# [4]	validation-rmse:14.49575
# [5]	validation-rmse:14.03387
# [6]	validation-rmse:13.60035
# [7]	validation-rmse:13.19350
# [8]	validation-rmse:12.81150
# [9]	validation-rmse:12.45339
# [10]	validation-rmse:12.11741
# [11]	validation-rmse:11.80261
# [12]	validation-rmse:11.50742
# [13]	validation-rmse:11.23084
# [14]	validation-rmse:10.97189
# [15]	validation-rmse:10.72923
# [16]	validation-rmse:10.50232
# [17]	validation-rmse:10.28953
# [18]	validation-rmse:10.09028
# [19]	validation-rmse:9.90385
# [20]	validation-rmse:9.72939
# [21]	validation-rmse:9.56648
# [22]	validation-rmse:9.41390
# [23]	validation-rmse:9.27083
# [24]	validation-rmse:9.13692
# [25]	validation-rmse:9.01153
# [26]	validation-rmse:8.89439
# [27]	validation-rmse:8.78470
# [28]	validation-rmse:8.68181
# [29]	validation-rmse:8.58572
# [00:01:17] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-cpython-37/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [0]	validation-rmse:16.09958
# [1]	validation-rmse:15.04264
# [2]	validation-rmse:14.10565
# [3]	validation-rmse:13.27676
# [4]	validation-rmse:12.54394
# [5]	validation-rmse:11.89792
# [6]	validation-rmse:11.32745
# [7]	validation-rmse:10.82543
# [8]	validation-rmse:10.38312
# [9]	validation-rmse:9.99387
# [10]	validation-rmse:9.65218
# [11]	validation-rmse:9.35170
# [12]	validation-rmse:9.08736
# [13]	validation-rmse:8.85539
# [14]	validation-rmse:8.65101
# [15]	validation-rmse:8.47179
# [16]	validation-rmse:8.31450
# [17]	validation-rmse:8.17523
# [18]	validation-rmse:8.05317
# [19]	validation-rmse:7.94512
# [20]	validation-rmse:7.84960
# [21]	validation-rmse:7.76490
# [22]	validation-rmse:7.69015
# [23]	validation-rmse:7.62368
# [24]	validation-rmse:7.56461
# [25]	validation-rmse:7.51183
# [26]	validation-rmse:7.46513
# [27]	validation-rmse:7.42344
# [28]	validation-rmse:7.38702
# [29]	validation-rmse:7.35396
# [00:01:28] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-cpython-37/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [0]	validation-rmse:15.20318
# [1]	validation-rmse:13.53708
# [2]	validation-rmse:12.20803
# [3]	validation-rmse:11.15107
# [4]	validation-rmse:10.32263
# [5]	validation-rmse:9.66124
# [6]	validation-rmse:9.14018
# [7]	validation-rmse:8.72598
# [8]	validation-rmse:8.40018
# [9]	validation-rmse:8.14474
# [10]	validation-rmse:7.94005
# [11]	validation-rmse:7.77712
# [12]	validation-rmse:7.64781
# [13]	validation-rmse:7.54611
# [14]	validation-rmse:7.46245
# [15]	validation-rmse:7.39566
# [16]	validation-rmse:7.34059
# [17]	validation-rmse:7.29614
# [18]	validation-rmse:7.26076
# [19]	validation-rmse:7.23256
# [20]	validation-rmse:7.20877
# [21]	validation-rmse:7.19010
# [22]	validation-rmse:7.17406
# [23]	validation-rmse:7.16136
# [24]	validation-rmse:7.15170
# [25]	validation-rmse:7.14252
# [26]	validation-rmse:7.13649
# [27]	validation-rmse:7.12998
# [28]	validation-rmse:7.12542
# [29]	validation-rmse:7.12169
# [00:01:38] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-cpython-37/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [0]	validation-rmse:16.61694
# [1]	validation-rmse:15.98535
# [2]	validation-rmse:15.39448
# [3]	validation-rmse:14.84132
# [4]	validation-rmse:14.32430
# [5]	validation-rmse:13.84088
# [6]	validation-rmse:13.38909
# [7]	validation-rmse:12.96713
# [8]	validation-rmse:12.57308
# [9]	validation-rmse:12.20540
# [10]	validation-rmse:11.86198
# [11]	validation-rmse:11.54189
# [12]	validation-rmse:11.24320
# [13]	validation-rmse:10.96446
# [14]	validation-rmse:10.70497
# [15]	validation-rmse:10.46300
# [16]	validation-rmse:10.23734
# [17]	validation-rmse:10.02710
# [18]	validation-rmse:9.83141
# [19]	validation-rmse:9.64908
# [20]	validation-rmse:9.47935
# [21]	validation-rmse:9.32149
# [22]	validation-rmse:9.17419
# [23]	validation-rmse:9.03681
# [24]	validation-rmse:8.90935
# [25]	validation-rmse:8.79048
# [26]	validation-rmse:8.67980
# [27]	validation-rmse:8.57687
# [28]	validation-rmse:8.48051
# [29]	validation-rmse:8.39131
# [00:01:59] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-cpython-37/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [0]	validation-rmse:16.65935
# [1]	validation-rmse:16.06519
# [2]	validation-rmse:15.50604
# [3]	validation-rmse:14.98118
# [4]	validation-rmse:14.48755
# [5]	validation-rmse:14.02472
# [6]	validation-rmse:13.58961
# [7]	validation-rmse:13.18219
# [8]	validation-rmse:12.79837
# [9]	validation-rmse:12.43975
# [10]	validation-rmse:12.10458
# [11]	validation-rmse:11.78995
# [12]	validation-rmse:11.49571
# [13]	validation-rmse:11.21841
# [14]	validation-rmse:10.95976
# [15]	validation-rmse:10.71851
# [16]	validation-rmse:10.49039
# [17]	validation-rmse:10.27854
# [18]	validation-rmse:10.07999
# [19]	validation-rmse:9.89470
# [20]	validation-rmse:9.72056
# [21]	validation-rmse:9.55810
# [22]	validation-rmse:9.40591
# [23]	validation-rmse:9.26431
# [24]	validation-rmse:9.13035
# [25]	validation-rmse:9.00606
# [26]	validation-rmse:8.88948
# [27]	validation-rmse:8.77990
# [28]	validation-rmse:8.67809
# [29]	validation-rmse:8.58201
# [00:02:14] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-cpython-37/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [0]	validation-rmse:16.12989
# [1]	validation-rmse:15.09566
# [2]	validation-rmse:14.17577
# [3]	validation-rmse:13.35846
# [4]	validation-rmse:12.63435
# [5]	validation-rmse:11.99350
# [6]	validation-rmse:11.42559
# [7]	validation-rmse:10.92273
# [8]	validation-rmse:10.47895
# [9]	validation-rmse:10.08645
# [10]	validation-rmse:9.74103
# [11]	validation-rmse:9.43659
# [12]	validation-rmse:9.16814
# [13]	validation-rmse:8.93110
# [14]	validation-rmse:8.72159
# ...
# [5]	validation-rmse:7.18386
# [6]	validation-rmse:7.11957
# [7]	validation-rmse:7.08634
# [8]	validation-rmse:7.06854
# [9]	validation-rmse:7.05907
# [10]	validation-rmse:7.05471
# [11]	validation-rmse:7.05166
# [12]	validation-rmse:7.04970
# [13]	validation-rmse:7.04924
# [14]	validation-rmse:7.05029
# [15]	validation-rmse:7.05025
# [16]	validation-rmse:7.05052
# [17]	validation-rmse:7.05104
# [18]	validation-rmse:7.05159
# [19]	validation-rmse:7.05211
# [20]	validation-rmse:7.05269
# [21]	validation-rmse:7.05291
# [22]	validation-rmse:7.05258
# [23]	validation-rmse:7.05246
# [24]	validation-rmse:7.05124
# [25]	validation-rmse:7.05141
# [26]	validation-rmse:7.04986
# [27]	validation-rmse:7.04974
# [28]	validation-rmse:7.04906
# [29]	validation-rmse:7.04930
# [00:11:24] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-cpython-37/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [0]	validation-rmse:10.44374
# [1]	validation-rmse:8.21532
# [2]	validation-rmse:7.48703
# [3]	validation-rmse:7.23314
# [4]	validation-rmse:7.13567
# [5]	validation-rmse:7.10271
# [6]	validation-rmse:7.08867
# [7]	validation-rmse:7.08176
# [8]	validation-rmse:7.07871
# [9]	validation-rmse:7.07837
# [10]	validation-rmse:7.07717
# [11]	validation-rmse:7.07679
# [12]	validation-rmse:7.07715
# [13]	validation-rmse:7.07722
# [14]	validation-rmse:7.07814
# [15]	validation-rmse:7.07693
# [16]	validation-rmse:7.07802
# [17]	validation-rmse:7.07966
# [18]	validation-rmse:7.08174
# [19]	validation-rmse:7.08043
# [20]	validation-rmse:7.07891
# [21]	validation-rmse:7.07774
# [22]	validation-rmse:7.07681
# [23]	validation-rmse:7.07597
# [24]	validation-rmse:7.07641
# [25]	validation-rmse:7.07540
# [26]	validation-rmse:7.07450
# [27]	validation-rmse:7.07602
# [28]	validation-rmse:7.07571
# [29]	validation-rmse:7.07547
# [00:11:35] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-cpython-37/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [0]	validation-rmse:16.43274
# [1]	validation-rmse:15.64435
# [2]	validation-rmse:14.92034
# [3]	validation-rmse:14.25588
# [4]	validation-rmse:13.64651
# [5]	validation-rmse:13.08853
# [6]	validation-rmse:12.57775
# [7]	validation-rmse:12.10977
# [8]	validation-rmse:11.68174
# [9]	validation-rmse:11.29036
# [10]	validation-rmse:10.93246
# [11]	validation-rmse:10.60518
# [12]	validation-rmse:10.30687
# [13]	validation-rmse:10.03418
# [14]	validation-rmse:9.78538
# [15]	validation-rmse:9.55812
# [16]	validation-rmse:9.35068
# [17]	validation-rmse:9.16114
# [18]	validation-rmse:8.98817
# [19]	validation-rmse:8.83081
# [20]	validation-rmse:8.68708
# [21]	validation-rmse:8.55512
# [22]	validation-rmse:8.43503
# [23]	validation-rmse:8.32538
# [24]	validation-rmse:8.22550
# [25]	validation-rmse:8.13356
# [26]	validation-rmse:8.04937
# [27]	validation-rmse:7.97306
# [28]	validation-rmse:7.90325
# [29]	validation-rmse:7.83831
# 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████| 50/50 [11:26<00:00, 13.73s/trial, best loss: 7.0453644887739735]

# %%
params = {
    'learning_rate': 0.3795086202637246,
    'max_depth': 55,
    'min_child_weight': 3.3288327276634258,
    'objective': 'reg:linear',
    'reg_alpha': 0.2945298494685302,
    'reg_lambda': 0.05017902854814832,
    'seed': 42
}

mlflow.xgboost.autolog()

booster = xgb.train(
    params=params,
    dtrain=train,
    num_boost_round=30,
    evals=[(valid, "validation")],
    early_stopping_rounds=15
)
# Out:
# 2023/05/25 08:28:10 INFO mlflow.utils.autologging_utils: Created MLflow autologging run with ID '2ad84216be84444aa495d9563dcbba74', which will track hyperparameters, performance metrics, model artifacts, and lineage information for the current xgboost workflow
# [08:28:10] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-cpython-37/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [0]	validation-rmse:12.96097
# [1]	validation-rmse:10.44925
# [2]	validation-rmse:9.01572
# [3]	validation-rmse:8.20427
# [4]	validation-rmse:7.73788
# [5]	validation-rmse:7.46677
# [6]	validation-rmse:7.30463
# [7]	validation-rmse:7.20706
# [8]	validation-rmse:7.14647
# [9]	validation-rmse:7.11023
# [10]	validation-rmse:7.08879
# [11]	validation-rmse:7.07359
# [12]	validation-rmse:7.06572
# [13]	validation-rmse:7.05686
# [14]	validation-rmse:7.05288
# [15]	validation-rmse:7.05060
# [16]	validation-rmse:7.04962
# [17]	validation-rmse:7.04906
# [18]	validation-rmse:7.04825
# [19]	validation-rmse:7.04773
# [20]	validation-rmse:7.04593
# [21]	validation-rmse:7.04492
# [22]	validation-rmse:7.04370
# [23]	validation-rmse:7.04387
# [24]	validation-rmse:7.04307
# [25]	validation-rmse:7.04336
# [26]	validation-rmse:7.04375
# [27]	validation-rmse:7.04330
# [28]	validation-rmse:7.04437
# [29]	validation-rmse:7.04536
# 2023/05/25 08:28:40 WARNING mlflow.xgboost: Failed to infer model signature: could not sample data to infer model signature: please ensure that autologging is enabled before constructing the dataset.

# %%
len(df_train), len(df_val)
# Out:
# (2421440, 2918187)

# %%
train_val_dict = prepare_training_and_validation_data(df_train, df_val)

# %%
train_val_dict['y_train'].shape
# Out:
# (2421440,)

# %%
from sklearn.linear_model import LinearRegression

# %%
lr = LinearRegression()
lr.fit(train_val_dict['X_train'], train_val_dict['y_train'])

y_pred = lr.predict(train_val_dict['X_val'])

mean_squared_error(train_val_dict['y_val'], y_pred, squared=False)
# Out:
# 5.414854617936158

# %%
import pickle

# %%
with open('models/lin_reg.bin', 'wb') as f_out:
    pickle.dump((dv, lr), f_out)

# %%
mlflow.set_experiment("lin-reg-model-save-experiment")
# Out:
# 2023/05/26 09:35:12 INFO mlflow.tracking.fluent: Experiment with name 'lin-reg-model-save-experiment' does not exist. Creating a new experiment.
# <Experiment: artifact_location='./mlruns/4', creation_time=1685073912380, experiment_id='4', last_update_time=1685073912380, lifecycle_stage='active', name='lin-reg-model-save-experiment', tags={}>

# %%
with mlflow.start_run():
    mlflow.set_tag("developer", "amogh")

    mlflow.log_param("train-data-path", "../../data/yellow_tripdata_2022-01.parquet")
    mlflow.log_param("val-data-path", "../../data/yellow_tripdata_2022-02.parquet")

    lr = LinearRegression()
    lr.fit(train_val_dict['X_train'], train_val_dict['y_train'])

    y_pred = lr.predict(train_val_dict['X_val'])

    rmse = mean_squared_error(y_pred, train_val_dict['y_val'], squared=False)
    
    mlflow.log_metric("rmse", rmse)
    
    mlflow.log_artifact(local_path="models/lin_reg.bin", artifact_path="models/pickle")

# %%
mlflow.xgboost.autolog(disable=True)

# %%
with mlflow.start_run():
    
    train = xgb.DMatrix(train_val_dict['X_train'], label=train_val_dict['y_train'])
    valid = xgb.DMatrix(train_val_dict['X_val'], label=train_val_dict['y_val'])
    
    params = {
        'learning_rate': 0.3795086202637246,
        'max_depth': 55,
        'min_child_weight': 3.3288327276634258,
        'objective': 'reg:linear',
        'reg_alpha': 0.2945298494685302,
        'reg_lambda': 0.05017902854814832,
        'seed': 42
    }
    
    mlflow.log_params(params)
    
    booster = xgb.train(
        params=params,
        dtrain=train,
        num_boost_round=50,
        evals=[(valid, "validation")],
        early_stopping_rounds=25
    )
    
    y_pred = booster.predict(valid)
    rmse = mean_squared_error(train_val_dict['y_val'], y_pred, squared=False)
    mlflow.log_metric("rmse", rmse)
    
    mlflow.xgboost.log_model(booster, artifact_path="models_mlflow")
# Out:
# [09:44:20] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-cpython-37/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [0]	validation-rmse:11.35125
# [1]	validation-rmse:8.43383
# [2]	validation-rmse:6.83550
# [3]	validation-rmse:5.99248
# [4]	validation-rmse:5.55507
# [5]	validation-rmse:5.32212
# [6]	validation-rmse:5.19453
# [7]	validation-rmse:5.12098
# [8]	validation-rmse:5.07598
# [9]	validation-rmse:5.04639
# [10]	validation-rmse:5.02762
# [11]	validation-rmse:5.01497
# [12]	validation-rmse:5.00866
# [13]	validation-rmse:5.00379
# [14]	validation-rmse:5.00017
# [15]	validation-rmse:4.99708
# [16]	validation-rmse:4.99200
# [17]	validation-rmse:4.98981
# [18]	validation-rmse:4.98808
# [19]	validation-rmse:4.98630
# [20]	validation-rmse:4.98466
# [21]	validation-rmse:4.98275
# [22]	validation-rmse:4.98103
# [23]	validation-rmse:4.97955
# [24]	validation-rmse:4.97799
# [25]	validation-rmse:4.97643
# [26]	validation-rmse:4.97401
# [27]	validation-rmse:4.97295
# [28]	validation-rmse:4.97183
# [29]	validation-rmse:4.97037
# [30]	validation-rmse:4.96936
# [31]	validation-rmse:4.96829
# [32]	validation-rmse:4.96712
# [33]	validation-rmse:4.96603
# [34]	validation-rmse:4.96486
# [35]	validation-rmse:4.96366
# [36]	validation-rmse:4.96250
# [37]	validation-rmse:4.96059
# [38]	validation-rmse:4.95927
# [39]	validation-rmse:4.95827
# [40]	validation-rmse:4.95757
# [41]	validation-rmse:4.95676
# [42]	validation-rmse:4.95562
# [43]	validation-rmse:4.95463
# [44]	validation-rmse:4.95296
# [45]	validation-rmse:4.95213
# [46]	validation-rmse:4.95140
# [47]	validation-rmse:4.95047
# [48]	validation-rmse:4.94985
# [49]	validation-rmse:4.94891

# %%
logged_model = 'runs:/0487df4008cd4f838aad1e07eb1d8d5d/models_mlflow'

# Load model as a PyFuncModel.
loaded_model = mlflow.pyfunc.load_model(logged_model)
# Out:
# [10:02:07] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-cpython-37/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.

# %%
loaded_model
# Out:
# mlflow.pyfunc.loaded_model:
#   artifact_path: models_mlflow
#   flavor: mlflow.xgboost
#   run_id: 0487df4008cd4f838aad1e07eb1d8d5d

# %%
xgboost_model = mlflow.xgboost.load_model(logged_model)
# Out:
# [10:04:14] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-cpython-37/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.

# %%
y_pred = xgboost_model.predict(valid)

# %%
y_pred
# Out:
# array([14.550037, 19.915255, 28.732475, ..., 15.989329, 10.005005,
#         8.948286], dtype=float32)

# %%
# Training GradientBoosting Regressor Algo for model registry video

# %%
from sklearn.ensemble import GradientBoostingRegressor

# %%
mlflow.set_experiment("model-registry-experiment-1")
# Out:
# 2023/05/27 18:26:08 INFO mlflow.tracking.fluent: Experiment with name 'model-registry-experiment-1' does not exist. Creating a new experiment.
# <Experiment: artifact_location='./mlruns/5', creation_time=1685192168608, experiment_id='5', last_update_time=1685192168608, lifecycle_stage='active', name='model-registry-experiment-1', tags={}>

# %%
with mlflow.start_run():
    
    learning_rate = 0.3795086202637246
    n_estimators = 50
    min_samples_leaf = 4
    max_depth = 55
    
    mlflow.log_param("learning_rate", learning_rate)
    mlflow.log_param("n_estimators", n_estimators)
    mlflow.log_param("min_samples_leaf", min_samples_leaf)
    mlflow.log_param("max_depth", max_depth)

    # params for gradient boosting is same as Xgboost parameter. Trying to train a new model for model registry.
    # Not looking for accurate models.
    gradient_model = GradientBoostingRegressor(
        learning_rate=learning_rate,
        n_estimators=n_estimators,
        min_samples_leaf=min_samples_leaf,
        max_depth=max_depth
    )
    
    gradient_model.fit(X_train, y_train)
    
    with open('models/gradient_boosting_model.bin', 'wb') as f_out:
        pickle.dump(gradient_model, f_out)
    
    y_pred = gradient_model.predict(X_val)
    
    rmse = mean_squared_error(y_val, y_pred, squared=False)
    
    mlflow.log_metric("rmse", rmse)
        
    mlflow.sklearn.log_model(gradient_model, artifact_path="models/pickle")

# %%
rmse
# Out:
# 7.054120161913282

# %%
with mlflow.start_run():
    
    train = xgb.DMatrix(train_val_dict['X_train'], label=train_val_dict['y_train'])
    valid = xgb.DMatrix(train_val_dict['X_val'], label=train_val_dict['y_val'])
    
    params = {
        'learning_rate': 0.3795086202637246,
        'max_depth': 55,
        'min_child_weight': 3.3288327276634258,
        'objective': 'reg:linear',
        'reg_alpha': 0.2945298494685302,
        'reg_lambda': 0.05017902854814832,
        'seed': 42
    }
    
    mlflow.log_params(params)
    
    booster = xgb.train(
        params=params,
        dtrain=train,
        num_boost_round=50,
        evals=[(valid, "validation")],
        early_stopping_rounds=25
    )
    
    y_pred = booster.predict(valid)
    rmse = mean_squared_error(train_val_dict['y_val'], y_pred, squared=False)
    mlflow.log_metric("rmse", rmse)
    
    mlflow.xgboost.log_model(booster, artifact_path="models_mlflow")
# Out:
# [18:36:26] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-cpython-37/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [0]	validation-rmse:11.35125
# [1]	validation-rmse:8.43383
# [2]	validation-rmse:6.83550
# [3]	validation-rmse:5.99248
# [4]	validation-rmse:5.55507
# [5]	validation-rmse:5.32212
# [6]	validation-rmse:5.19453
# [7]	validation-rmse:5.12098
# [8]	validation-rmse:5.07598
# [9]	validation-rmse:5.04639
# [10]	validation-rmse:5.02762
# [11]	validation-rmse:5.01497
# [12]	validation-rmse:5.00866
# [13]	validation-rmse:5.00379
# [14]	validation-rmse:5.00017
# [15]	validation-rmse:4.99708
# [16]	validation-rmse:4.99200
# [17]	validation-rmse:4.98981
# [18]	validation-rmse:4.98808
# [19]	validation-rmse:4.98630
# [20]	validation-rmse:4.98466
# [21]	validation-rmse:4.98275
# [22]	validation-rmse:4.98103
# [23]	validation-rmse:4.97955
# [24]	validation-rmse:4.97799
# [25]	validation-rmse:4.97643
# [26]	validation-rmse:4.97401
# [27]	validation-rmse:4.97295
# [28]	validation-rmse:4.97183
# [29]	validation-rmse:4.97037
# [30]	validation-rmse:4.96936
# [31]	validation-rmse:4.96829
# [32]	validation-rmse:4.96712
# [33]	validation-rmse:4.96603
# [34]	validation-rmse:4.96486
# [35]	validation-rmse:4.96366
# [36]	validation-rmse:4.96250
# [37]	validation-rmse:4.96059
# [38]	validation-rmse:4.95927
# [39]	validation-rmse:4.95827
# [40]	validation-rmse:4.95757
# [41]	validation-rmse:4.95676
# [42]	validation-rmse:4.95562
# [43]	validation-rmse:4.95463
# [44]	validation-rmse:4.95296
# [45]	validation-rmse:4.95213
# [46]	validation-rmse:4.95140
# [47]	validation-rmse:4.95047
# [48]	validation-rmse:4.94985
# [49]	validation-rmse:4.94891

# %%
with mlflow.start_run():
    
    lr = LinearRegression()
    lr.fit(train_val_dict['X_train'], train_val_dict['y_train'])
    
    with open('models/linear_regression.bin', 'wb') as f_out:
        pickle.dump(gradient_model, f_out)
    

    y_pred = lr.predict(train_val_dict['X_val'])

    rmse = mean_squared_error(train_val_dict['y_val'], y_pred, squared=False)
    
    mlflow.log_metric("rmse", rmse)
    
    mlflow.sklearn.log_model(lr, artifact_path="models_mlflow")

# %%
mlflow.sklearn
# Out:
# <module 'mlflow.sklearn' from '/Users/temp/Documents/projects/ml_ops_zoomcamp/exp-tracking-env/lib/python3.7/site-packages/mlflow/sklearn/__init__.py'>

# %%
from mlflow.tracking import MlflowClient

MLFLOW_TRACKING_URI = 'sqlite:///mlflow.db'

client = MlflowClient(tracking_uri=MLFLOW_TRACKING_URI)

# %%
client.list_experiments()
# Out:
# /Users/temp/Documents/projects/ml_ops_zoomcamp/exp-tracking-env/lib/python3.7/site-packages/ipykernel_launcher.py:1: FutureWarning: ``mlflow.tracking.client.MlflowClient.list_experiments`` is deprecated. This method will be removed in a future release. Use ``search_experiments()`` instead.
#   """Entry point for launching an IPython kernel.
# [<Experiment: artifact_location='./mlruns/0', creation_time=1684809513150, experiment_id='0', last_update_time=1684809513150, lifecycle_stage='active', name='Default', tags={}>,
#  <Experiment: artifact_location='./mlruns/1', creation_time=1684849967310, experiment_id='1', last_update_time=1684849967310, lifecycle_stage='active', name='nyc-taxi-experiment', tags={}>,
#  <Experiment: artifact_location='./mlruns/2', creation_time=1684949192625, experiment_id='2', last_update_time=1684949192625, lifecycle_stage='active', name='xgboost-autlog-experiment', tags={}>,
#  <Experiment: artifact_location='./mlruns/3', creation_time=1684983467538, experiment_id='3', last_update_time=1684983467538, lifecycle_stage='active', name='xgboost-autlog-experiment-2', tags={}>,
#  <Experiment: artifact_location='./mlruns/4', creation_time=1685073912380, experiment_id='4', last_update_time=1685073912380, lifecycle_stage='active', name='lin-reg-model-save-experiment', tags={}>,
#  <Experiment: artifact_location='./mlruns/5', creation_time=1685192168608, experiment_id='5', last_update_time=1685192168608, lifecycle_stage='active', name='model-registry-experiment-1', tags={}>]

# %%
client.create_experiment(name="my-cool-experiment")
# Out:
# '6'

# %%
from mlflow.entities import ViewType

runs = client.search_runs(
    experiment_ids='5',
    filter_string="metrics.rmse < 9",
    run_view_type=ViewType.ACTIVE_ONLY,
    max_results=10,
    order_by=["metrics.rmse ASC"]
)

# %% [markdown]
# for run in runs:
#     print(f"run_id={run.info.run_id}, rmse={run.data.metrics['rmse']:.4f}")

# %%
for run in runs:
    print(f"run_id={run.info.run_id}, rmse={run.data.metrics['rmse']:.4f}")
# Out:
# run_id=5823f93e73b149c388e8a738e4b7a80b, rmse=4.9489
# run_id=0614c1cd69914ab59ec99a136d1084b7, rmse=5.4149
# run_id=44c430ceb9924bd59bb30f3db052d670, rmse=5.4149
# run_id=238d460301264dd89be4831ef90e5d8d, rmse=7.0541
# run_id=209d3c6107e343c3b86657161f7c45de, rmse=7.0541

# %%
run_id = '209d3c6107e343c3b86657161f7c45de'
model_uri = f"runs:/{run_id}/model"
mlflow.register_model(model_uri=model_uri, name="nyc-taxi-aggressor")
# Out:
# Registered model 'nyc-taxi-aggressor' already exists. Creating a new version of this model...
# 2023/05/28 16:52:58 INFO mlflow.tracking._model_registry.client: Waiting up to 300 seconds for model version to finish creation.                     Model name: nyc-taxi-aggressor, version 3
# Created version '3' of model 'nyc-taxi-aggressor'.
# <ModelVersion: creation_timestamp=1685272978676, current_stage='None', description=None, last_updated_timestamp=1685272978676, name='nyc-taxi-aggressor', run_id='209d3c6107e343c3b86657161f7c45de', run_link=None, source='./mlruns/5/209d3c6107e343c3b86657161f7c45de/artifacts/model', status='READY', status_message=None, tags={}, user_id=None, version=3>

# %%
model_uri
# Out:
# 'runs:/209d3c6107e343c3b86657161f7c45de/model'

# %%
model_name = "nyc-taxi-aggressor"
latest_versions = client.get_latest_versions(name=model_name)

for version in latest_versions:
    print(f"version: {version.version}, stage: {version.current_stage}")
# Out:
# version: 1, stage: Production
# version: 2, stage: Staging
# version: 3, stage: None

# %%
client.transition_model_version_stage(
    name=model_name,
    version=3,
    stage="Staging",
    archive_existing_versions=False
)
# Out:
# <ModelVersion: creation_timestamp=1685272978676, current_stage='Staging', description=None, last_updated_timestamp=1685273650074, name='nyc-taxi-aggressor', run_id='209d3c6107e343c3b86657161f7c45de', run_link=None, source='./mlruns/5/209d3c6107e343c3b86657161f7c45de/artifacts/model', status='READY', status_message=None, tags={}, user_id=None, version=3>

# %%
from datetime import datetime
current_date = datetime.now().date().strftime("%Y-%m-%d")
client.update_model_version(
    version=3,
    name=model_name,
    description=f"The model version 3 was transitioned to Staging on {current_date}"
)
# Out:
# <ModelVersion: creation_timestamp=1685272978676, current_stage='Staging', description='The model version 3 was transitioned to Staging on 2023-05-28', last_updated_timestamp=1685273847632, name='nyc-taxi-aggressor', run_id='209d3c6107e343c3b86657161f7c45de', run_link=None, source='./mlruns/5/209d3c6107e343c3b86657161f7c45de/artifacts/model', status='READY', status_message=None, tags={}, user_id=None, version=3>

# %% [markdown]
# ---------- Module 2.6 MLFlow in practice ----------------------

# %%
import os

os.environ["AWS_PROFILE"] = "default"

# %%
TRACKING_URI = "ec2-3-141-4-192.us-east-2.compute.amazonaws.com"

# %%
mlflow.set_tracking_uri(f"http://{TRACKING_URI}:5000")

# %%
print(f"tracking URI = {mlflow.get_tracking_uri()}")
# Out:
# tracking URI = http://ec2-3-141-4-192.us-east-2.compute.amazonaws.com:5000

# %%
mlflow.get_tracking_uri()
# Out:
# 'http://ec2-3-141-4-192.us-east-2.compute.amazonaws.com:5000'

# %%
mlflow.search_experiments()
# Out:
# [<Experiment: artifact_location='s3://mlflow-artifacts-remote-amogh/0', creation_time=1685379456844, experiment_id='0', last_update_time=1685379456844, lifecycle_stage='active', name='Default', tags={}>]

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.datasets import load_iris
from sklearn.metrics import accuracy_score

# %%
mlflow.set_experiment("my-experiment-1")
# Out:
# 2023/05/30 19:29:36 INFO mlflow.tracking.fluent: Experiment with name 'my-experiment-1' does not exist. Creating a new experiment.
# <Experiment: artifact_location='s3://mlflow-artifacts-remote-amogh/1', creation_time=1685454765088, experiment_id='1', last_update_time=1685454765088, lifecycle_stage='active', name='my-experiment-1', tags={}>

# %%
with mlflow.start_run():
    
    X, y = load_iris(return_X_y=True)
    
    params = {"C": 0.1, "random_state": 42}
    mlflow.log_params(params)
    
    lr = LogisticRegression(**params).fit(X, y)
    
    y_pred = lr.predict(X)
    mlflow.log_metric("accuracy", accuracy_score(y, y_pred))
    
    mlflow.sklearn.log_model(lr, artifact_path="models")
    print(f"default artifact URI: '{mlflow.get_artifact_uri()}'")
# Out:
# ---------------------------------------------------------------------------
# ProfileNotFound                           Traceback (most recent call last)
# /var/folders/qv/05y5x0zd7ws6sng8_4bv2zw00000gp/T/ipykernel_89407/3804226268.py in <module>
#      11     mlflow.log_metric("accuracy", accuracy_score(y, y_pred))
#      12
# ---> 13     mlflow.sklearn.log_model(lr, artifact_path="models")
#      14     print(f"default artifact URI: '{mlflow.get_artifact_uri()}'")
#
# ~/Documents/projects/ml_ops_zoomcamp/exp-tracking-env/lib/python3.7/site-packages/mlflow/sklearn/__init__.py in log_model(sk_model, artifact_path, conda_env, code_paths, serialization_format, registered_model_name, signature, input_example, await_registration_for, pip_requirements, extra_pip_requirements, pyfunc_predict_fn)
#     418         pip_requirements=pip_requirements,
#     419         extra_pip_requirements=extra_pip_requirements,
# --> 420         pyfunc_predict_fn=pyfunc_predict_fn,
#     421     )
#     422
#
# ~/Documents/projects/ml_ops_zoomcamp/exp-tracking-env/lib/python3.7/site-packages/mlflow/models/model.py in log(cls, artifact_path, flavor, registered_model_name, await_registration_for, **kwargs)
#     372             mlflow_model = cls(artifact_path=artifact_path, run_id=run_id)
#     373             flavor.save_model(path=local_path, mlflow_model=mlflow_model, **kwargs)
# --> 374             mlflow.tracking.fluent.log_artifacts(local_path, mlflow_model.artifact_path)
#     375             try:
#     376                 mlflow.tracking.fluent._record_logged_model(mlflow_model)
#
# ~/Documents/projects/ml_ops_zoomcamp/exp-tracking-env/lib/python3.7/site-packages/mlflow/tracking/fluent.py in log_artifacts(local_dir, artifact_path)
#     811     """
#     812     run_id = _get_or_start_run().info.run_id
# --> 813     MlflowClient().log_artifacts(run_id, local_dir, artifact_path)
#     814
#     815
#
# ~/Documents/projects/ml_ops_zoomcamp/exp-tracking-env/lib/python3.7/site-packages/mlflow/tracking/client.py in log_artifacts(self, run_id, local_dir, artifact_path)
#    1180             is_dir: True
#    1181         """
# -> 1182         self._tracking_client.log_artifacts(run_id, local_dir, artifact_path)
#    1183
#    1184     @contextlib.contextmanager
#
# ~/Documents/projects/ml_ops_zoomcamp/exp-tracking-env/lib/python3.7/site-packages/mlflow/tracking/_tracking_service/client.py in log_artifacts(self, run_id, local_dir, artifact_path)
#     467         :param artifact_path: If provided, the directory in ``artifact_uri`` to write to.
#     468         """
# --> 469         self._get_artifact_repo(run_id).log_artifacts(local_dir, artifact_path)
#     470
#     471     def list_artifacts(self, run_id, path=None):
#
# ~/Documents/projects/ml_ops_zoomcamp/exp-tracking-env/lib/python3.7/site-packages/mlflow/store/artifact/s3_artifact_repo.py in log_artifacts(self, local_dir, artifact_path)
#     131         if artifact_path:
#     132             dest_path = posixpath.join(dest_path, artifact_path)
# --> 133         s3_client = self._get_s3_client()
#     134         local_dir = os.path.abspath(local_dir)
#     135         for (root, _, filenames) in os.walk(local_dir):
#
# ~/Documents/projects/ml_ops_zoomcamp/exp-tracking-env/lib/python3.7/site-packages/mlflow/store/artifact/s3_artifact_repo.py in _get_s3_client(self)
#     104         timestamp = int(_get_utcnow_timestamp() / _MAX_CACHE_SECONDS)
#     105
# --> 106         return _cached_get_s3_client(signature_version, s3_endpoint_url, verify, timestamp)
#     107
#     108     def _upload_file(self, s3_client, local_file, bucket, key):
#
# ~/Documents/projects/ml_ops_zoomcamp/exp-tracking-env/lib/python3.7/site-packages/mlflow/store/artifact/s3_artifact_repo.py in _cached_get_s3_client(signature_version, s3_endpoint_url, verify, timestamp)
#      60         config=Config(signature_version=signature_version),
#      61         endpoint_url=s3_endpoint_url,
# ---> 62         verify=verify,
#      63     )
#      64
#
# ~/Documents/projects/ml_ops_zoomcamp/exp-tracking-env/lib/python3.7/site-packages/boto3/__init__.py in client(*args, **kwargs)
#      90     See :py:meth:`boto3.session.Session.client`.
#      91     """
# ---> 92     return _get_default_session().client(*args, **kwargs)
#      93
#      94
#
# ~/Documents/projects/ml_ops_zoomcamp/exp-tracking-env/lib/python3.7/site-packages/boto3/session.py in client(self, service_name, region_name, api_version, use_ssl, verify, endpoint_url, aws_access_key_id, aws_secret_access_key, aws_session_token, config)
#     307             aws_secret_access_key=aws_secret_access_key,
#     308             aws_session_token=aws_session_token,
# --> 309             config=config,
#     310         )
#     311
#
# ~/Documents/projects/ml_ops_zoomcamp/exp-tracking-env/lib/python3.7/site-packages/botocore/session.py in create_client(self, service_name, region_name, api_version, use_ssl, verify, endpoint_url, aws_access_key_id, aws_secret_access_key, aws_session_token, config)
#     916             config = default_client_config
#     917
# --> 918         region_name = self._resolve_region_name(region_name, config)
#     919
#     920         # Figure out the verify value base on the various
#
# ~/Documents/projects/ml_ops_zoomcamp/exp-tracking-env/lib/python3.7/site-packages/botocore/session.py in _resolve_region_name(self, region_name, config)
#     998                 region_name = config.region_name
#     999             else:
# -> 1000                 region_name = self.get_config_variable('region')
#    1001
#    1002         validate_region_name(region_name)
#
# ~/Documents/projects/ml_ops_zoomcamp/exp-tracking-env/lib/python3.7/site-packages/botocore/session.py in get_config_variable(self, logical_name, methods)
#     316             )
#     317         return self.get_component('config_store').get_config_variable(
# --> 318             logical_name
#     319         )
#     320
#
# ~/Documents/projects/ml_ops_zoomcamp/exp-tracking-env/lib/python3.7/site-packages/botocore/configprovider.py in get_config_variable(self, logical_name)
#     424             return None
#     425         provider = self._mapping[logical_name]
# --> 426         return provider.provide()
#     427
#     428     def get_config_provider(self, logical_name):
#
# ~/Documents/projects/ml_ops_zoomcamp/exp-tracking-env/lib/python3.7/site-packages/botocore/configprovider.py in provide(self)
#     626         """
#     627         for provider in self._providers:
# --> 628             value = provider.provide()
#     629             if value is not None:
#     630                 return self._convert_type(value)
#
# ~/Documents/projects/ml_ops_zoomcamp/exp-tracking-env/lib/python3.7/site-packages/botocore/configprovider.py in provide(self)
#     716     def provide(self):
#     717         """Provide a value from a config file property."""
# --> 718         scoped_config = self._session.get_scoped_config()
#     719         if isinstance(self._config_var_name, tuple):
#     720             section_config = scoped_config.get(self._config_var_name[0])
#
# ~/Documents/projects/ml_ops_zoomcamp/exp-tracking-env/lib/python3.7/site-packages/botocore/session.py in get_scoped_config(self)
#     414             # exist (even if it's the default profile) otherwise
#     415             # we complain.
# --> 416             raise ProfileNotFound(profile=profile_name)
#     417         else:
#     418             return profile_map[profile_name]
#
# ProfileNotFound: The config profile (default) could not be found
